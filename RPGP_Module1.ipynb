# %% [markdown]
# <a href="https://colab.research.google.com/github/Parveen2327/TCW-RPGP-DS01-02/blob/main/RPGP_Module1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# India Literacy Data - 2011 Census

# %% [markdown]
# I chose this dataset because it offers a practical entry point into data analysis with NumPy, Pandas, and Python. Its manageable size and real-world context makes it easy to grasp fundamental concepts. I can use Pandas to read and organize the data, NumPy to perform calculations, and Python to tie everything together. Working with real-world data like this helps me understand how these tools are applied in practical scenarios, making it more engaging and relevant.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Literacy Data 2011.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                     District         State  Literacy
# 0           1                        Thane   Maharashtra     84.53
# 1           2   North Twenty Four Parganas   West Bengal     84.06
# 2           3                    Bangalore     Karnataka     87.67
# 3           4                         Pune   Maharashtra     86.15
# 4           5              Mumbai Suburban   Maharashtra     89.91

# %%
df.tail()
# Out:
#      Unnamed: 0          District                         State  Literacy
# 635         636          Nicobars   Andaman And Nicobar Islands     78.06
# 636         637       Upper Siang             Arunachal Pradesh     59.99
# 637         638   Lahul and Spiti              Himachal Pradesh     76.81
# 638         639             Anjaw             Arunachal Pradesh     56.46
# 639         640     Dibang Valley             Arunachal Pradesh     64.10

# %%
df.shape
# Out:
# (640, 4)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'District', 'State', 'Literacy'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  640 non-null    int64
#  1   District    640 non-null    object
#  2   State       640 non-null    object
#  3   Literacy    640 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 20.1+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0                     District                         State  \
# 0             1                        Thane                   Maharashtra
# 1             2   North Twenty Four Parganas                   West Bengal
# 2             3                    Bangalore                     Karnataka
# 3             4                         Pune                   Maharashtra
# 4             5              Mumbai Suburban                   Maharashtra
# ..          ...                          ...                           ...
# 635         636                     Nicobars   Andaman And Nicobar Islands
# 636         637                  Upper Siang             Arunachal Pradesh
# 637         638              Lahul and Spiti              Himachal Pradesh
# 638         639                        Anjaw             Arunachal Pradesh
# 639         640                Dibang Valley             Arunachal Pradesh
#
#      Literacy
# 0       84.53
# ...

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0   District           State    Literacy
# count   640.000000        640             640  640.000000
# unique         NaN        634              35         NaN
# top            NaN   Hamirpur   Uttar Pradesh         NaN
# freq           NaN          2              71         NaN
# mean    320.500000        NaN             NaN   72.308422
# std     184.896367        NaN             NaN   10.488816
# min       1.000000        NaN             NaN   36.100000
# 25%     160.750000        NaN             NaN   65.095000
# 50%     320.500000        NaN             NaN   72.170000
# 75%     480.250000        NaN             NaN   79.962500
# max     640.000000        NaN             NaN   97.910000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# District      0
# State         0
# Literacy      0
# dtype: int64

# %%
df[df['Literacy'] > 95]
# Out:
#      Unnamed: 0         District        State  Literacy
# 103         104        Ernakulam       Kerala     95.89
# 109         110         Thrissur       Kerala     95.08
# 113         114        Kozhikode       Kerala     95.08
# 169         170           Kannur       Kerala     95.10
# 214         215        Alappuzha       Kerala     95.72
# 233         234         Kottayam       Kerala     97.21
# 397         398   Pathanamthitta       Kerala     96.55
# 557         558           Aizawl      Mizoram     97.89
# 609         610         Champhai      Mizoram     95.91
# 625         626         Serchhip      Mizoram     97.91
# 634         635             Mahe   Puducherry     97.87

# %%
df.sort_values(by='Literacy')
# Out:
#      Unnamed: 0         District            State  Literacy
# 497         498        Alirajpur   Madhya Pradesh     36.10
# 580         581          Bijapur     Chhattisgarh     40.86
# 539         540        Dantewada     Chhattisgarh     42.12
# 439         440           Jhabua   Madhya Pradesh     43.30
# 391         392     Nabarangapur           Orissa     46.43
# ..          ...              ...              ...       ...
# 397         398   Pathanamthitta           Kerala     96.55
# 233         234         Kottayam           Kerala     97.21
# 634         635             Mahe       Puducherry     97.87
# 557         558           Aizawl          Mizoram     97.89
# 625         626         Serchhip          Mizoram     97.91
#
# [640 rows x 4 columns]

# %%
# Find districts with exactly 50% literacy
df[df['Literacy'] == 97.21][['District', 'State', 'Literacy']]
# Out:
#       District    State  Literacy
# 233   Kottayam   Kerala     97.21

# %% [markdown]
# **Inference** :
#
# **Variation in Literacy**: There is a significant variation in literacy rates across different districts in India. This suggests that factors influencing literacy are not uniform across the country.
#
# **Geographical Patterns**: Certain states (like Kerala and Mizoram, as seen in the high literacy districts) appear to have generally **higher** literacy rates than others. Conversely, some states (like Madhya Pradesh and Chhattisgarh, where some of the **lowest **literacy districts are located) may have lower average literacy rates.
#
# **Potential for Further Investigation**: The range and variation in literacy rates indicate that there's scope for deeper analysis to understand the factors contributing to high and low literacy in different regions. This could involve looking at socioeconomic factors, government initiatives, infrastructure, etc., if such data were available.
